# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load data

# %%
df = pd.read_parquet('../data/cleaned.parquet')
df.shape
# Out:
# (4646773, 23)

# %% [markdown]
# ## Explore
