# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load data

# %%
df = pd.read_parquet('../data/cleaned.parquet')
df.shape
# Out:
# (4646773, 23)

# %% [markdown]
# ## Explore

# %% [markdown]
# Classes ratio

# %%
df['FlagImpaye'].value_counts(normalize=True)
# Out:
# FlagImpaye
# False    0.993545
# True     0.006455
# Name: proportion, dtype: float64

# %% [markdown]
# Count of NA per column

# %%
df.isna().sum()
# Out:
# ZIBZIN                      0
# IDAvisAutorisationCheque    0
# FlagImpaye                  0
# Montant                     0
# DateTransaction             0
# CodeDecision                0
# VerifianceCPT1              0
# VerifianceCPT2              0
# VerifianceCPT3              0
# D2CB                        0
# ScoringFP1                  0
# ScoringFP2                  0
# ScoringFP3                  0
# TauxImpNb_RB                0
# TauxImpNB_CPM               0
# EcartNumCheq                0
# NbrMagasin3J                0
# DiffDateTr1                 0
# DiffDateTr2                 0
# DiffDateTr3                 0
# CA3TRetMtt                  0
# CA3TR                       0
# Heure                       0
# dtype: int64
