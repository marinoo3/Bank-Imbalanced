# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Load data

# %%
df = pd.read_table('../data/guillaume.txt', sep=';', decimal=',')
# Out:
# /var/folders/33/q1g3v5v53ps670nqjs6hgvjr0000gn/T/ipykernel_5111/3917622734.py:1: DtypeWarning: Columns (0: IDAvisAutorisationCheque, 1: FlagImpaye, 2: Montant, 3: CodeDecision, 4: VerifianceCPT1, 5: VerifianceCPT2, 6: VerifianceCPT3, 7: D2CB, 8: ScoringFP1, 9: ScoringFP2, 10: ScoringFP3, 11: TauxImpNb_RB, 12: TauxImpNB_CPM, 13: EcartNumCheq, 14: NbrMagasin3J, 15: DiffDateTr1, 16: DiffDateTr2, 17: DiffDateTr3, 18: CA3TRetMtt, 19: CA3TR, 20: Heure) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_table('guillaume.txt', sep=';', decimal=',')

# %% [markdown]
# This dtype warning shows there is something inconsistant with the formatting of the dataset

# %%
df.shape
# Out:
# (4646774, 23)

# %%
df['IDAvisAutorisationCheque'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df['IDAvisAutorisationCheque'].astype(int)
#
# File ~/Documents/GitHub/Bank-Imbalanced/imbalanced-env/lib/python3.11/site-packages/pandas/core/generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File ~/Documents/GitHub/Bank-Imbalanced/imbalanced-env/lib/python3.11/site-packages/pandas/core/internals/managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# ...

# %%
df[df['IDAvisAutorisationCheque'] == 'IDAvisAutorisationCheque'].index
# Out:
# RangeIndex(start=1956360, stop=1956361, step=1)

# %% [markdown]
# Looks like there is a duplicate of the column names at index `1956360`

# %%
print(df.iloc[1956360])
# Out:
# ZIBZIN                      A011010002908105209831316
# IDAvisAutorisationCheque                     78643047
# FlagImpaye                                          0
# Montant                            54,289999999999999
# DateTransaction                   2017-02-01 07:48:48
# CodeDecision                                        0
# VerifianceCPT1                                      1
# VerifianceCPT2                                      1
# VerifianceCPT3                                      1
# D2CB                                              267
# ScoringFP1                                          0
# ScoringFP2                                          0
# ScoringFP3                                          0
# TauxImpNb_RB                       110,05692599620494
# TauxImpNB_CPM                      53,554233554497365
# EcartNumCheq                                        0
# NbrMagasin3J                                        1
# ...

# %% [markdown]
# Lets try to fix the dtypes and reimport the data

# %%
# Manually set dtypes for each column (based on variable description from project file)
supposed_dtypes = {
    'ZIBZIN': str,
    'IDAvisAutorisationCheque': int,
    'FlagImpaye': bool,
    'Montant': float,
    'DateTransaction': str,
    'CodeDecision': int,
    'VerifianceCPT1': int,
    'VerifianceCPT2': int,
    'VerifianceCPT3': int,
    'D2CB': int,
    'ScoringFP1': float,
    'ScoringFP2': float,
    'ScoringFP3': float,
    'TauxImpNb_RB': float,
    'TauxImpNB_CPM': float,
    'EcartNumCheq': int,
    'NbrMagasin3J': int,
    'DiffDateTr1': float,
    'DiffDateTr2': float,
    'DiffDateTr3': float,
    'CA3TRetMtt': float,
    'CA3TR': float,
    'Heure': int
}

# Reimport the data skipping the row 1956360
df = pd.read_table('guillaume.txt', sep=';', decimal=',', skiprows=[1956360+1], dtype=supposed_dtypes)

# %% [markdown]
# Export the data as parquet (better for large dataset + save variable types)

# %%
df.to_parquet('../data/cleaned.parquet', engine='fastparquet')
